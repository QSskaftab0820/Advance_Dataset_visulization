# %%
#MOVIE RATING ANALYTICS (ADVANCED VISUALIZATION)

# %%
import pandas as pd
import os

# %%
os.getcwd() # if you want to change the working directory
# Out:
# 'C:\\Users\\akaft'

# %%
movies=pd.read_csv(r"C:\Users\akaft\Downloads\Movie-Rating.csv")
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
movies.isna()#.sum()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
movies.isna().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.describe().T
# Out:
#                            count         mean        std     min     25%  \
# Rotten Tomatoes Ratings %  559.0    47.309481  26.413091     0.0    25.0
# Audience Ratings %         559.0    58.744186  16.826887     0.0    47.0
# Budget (million $)         559.0    50.236136  48.731817     0.0    20.0
# Year of release            559.0  2009.152057   1.362632  2007.0  2008.0
#
#                               50%     75%     max
# Rotten Tomatoes Ratings %    46.0    70.0    97.0
# Audience Ratings %           58.0    72.0    96.0
# Budget (million $)           35.0    65.0   300.0
# Year of release            2009.0  2010.0  2011.0

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating','AudienceRatings', 'BudgetMillion','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings')

# %%
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings',kind='hex')

# %%
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings',kind='reg')
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings',kind='kde')
plt.show()

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings',kind='scatter')
plt.show()

# %%
m1 = sns.distplot(movies.AudienceRatings)

# %%
plt.show()

# %%
m1 = sns.distplot(movies.CriticRating)

# %%
plt.show()

# %%
m1 = sns.displot(movies.CriticRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRatings,bins=10)
plt.show()

# %%
#sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRatings, bins = 15)

# %%
plt.show()

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = plt.hist(movies.AudienceRatings, bins=20)

# %%
plt.show()

# %%
n1 = plt.hist(movies.CriticRating, bins=20) #uniform distribution

# %%
plt.show()

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
plt.hist(movies.BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
movies[movies.Genre == 'Action'].shape[0]#it showing only  no of rows of actions movies
# Out:
# 154

# %%
#Below plots are stacked histogram because overlaped
print(plt.hist(movies[movies.Genre == 'Action'].BudgetMillion, bins = 20))
print(plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion, bins = 20))
print(plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion, bins = 20))
print(plt.ylim())
print(plt.legend())
print(plt.show())
# Out:
# (array([ 7., 22., 27., 16.,  8., 16.,  9.,  5.,  7.,  6., 12.,  2.,  3.,
#         8.,  1.,  2.,  1.,  1.,  0.,  1.]), array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.,
#        165., 180., 195., 210., 225., 240., 255., 270., 285., 300.]), <BarContainer object of 20 artists>)
# (array([2., 9., 3., 6., 1., 1., 3., 2., 1., 1., 3., 1., 0., 1., 0., 0., 1.,
#        0., 0., 1.]), array([  4.  ,  13.05,  22.1 ,  31.15,  40.2 ,  49.25,  58.3 ,  67.35,
#         76.4 ,  85.45,  94.5 , 103.55, 112.6 , 121.65, 130.7 , 139.75,
#        148.8 , 157.85, 166.9 , 175.95, 185.  ]), <BarContainer object of 20 artists>)
# (array([14., 11., 27., 13., 13.,  5.,  5.,  3.,  4.,  2.,  2.,  0.,  0.,
#         1.,  0.,  0.,  0.,  0.,  0.,  1.]), array([  0. ,   7.5,  15. ,  22.5,  30. ,  37.5,  45. ,  52.5,  60. ,
#         67.5,  75. ,  82.5,  90. ,  97.5, 105. , 112.5, 120. , 127.5,
#        135. , 142.5, 150. ]), <BarContainer object of 20 artists>)
# (0.0, 28.35)
# Legend
# None

# %%
action_movies = movies[movies.Genre == 'Action'][['Genre', 'BudgetMillion']]
print(action_movies)
# Out:
#       Genre  BudgetMillion
# 2    Action             20
# 5    Action            200
# 15   Action             35
# 29   Action             20
# 30   Action             20
# ..      ...            ...
# 531  Action            130
# 542  Action             35
# 546  Action            150
# 547  Action            160
# 557  Action             24
#
# [154 rows x 2 columns]

# %%
movies.BudgetMillion.describe()
# Out:
# count    559.000000
# mean      50.236136
# std       48.731817
# min        0.000000
# 25%       20.000000
# 50%       35.000000
# 75%       65.000000
# max      300.000000
# Name: BudgetMillion, dtype: float64

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillion,\
          movies[movies.Genre == 'Drama'].BudgetMillion, \
          movies[movies.Genre == 'Thriller'].BudgetMillion, \
          movies[movies.Genre == 'Comedy'].BudgetMillion],
         bins = 20, stacked = True)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillion, bins=20, label='Action')
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion, bins=20, label='Thriller')
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion, bins=20, label='Drama')
plt.legend()
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
movies['Genre']
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
for gen in movies.Genre.unique():
    print(gen)
# Out:
# Comedy
# Adventure
# Action
# Horror
# Drama
# Romance
# Thriller

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillion  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# ...

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                  fit_reg=False)

# %%
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False, hue = 'Genre')

# %%
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False, hue = 'Genre', height = 10,aspect=1)

# %%
plt.show()

# %%
# Kernal Density Estimate plot ( KDE PLOT) 
# how can i visulize audience rating & critics rating . using scatterplot

# %%
k1 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRatings')
plt.figure(figsize=(10,6))

# where do u find more density and how density is distibuted across from the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
plt.show()

# %%
k1 = sns.kdeplot(data=movies,x = 'CriticRating', y='AudienceRatings',shade = True,shade_lowest=False,cmap='Reds')

# %%
plt.show()

# %%
k1 = sns.kdeplot(data=movies,x = 'CriticRating', y='AudienceRatings',shade = False,shade_lowest=True,cmap='Reds')

# %%
plt.show()

# %%
k1 = sns.kdeplot(data=movies,x = 'CriticRating', y='AudienceRatings',shade = True,shade_lowest=True,cmap = 'Reds')

# %%
plt.show()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data=movies,x = 'CriticRating', y='AudienceRatings',shade_lowest=False,cmap='Reds')

# %%
plt.show()

# %%
k1 = sns.kdeplot(data=movies,x = 'CriticRating', y='AudienceRatings',shade = True,cmap='Greens_r')

# %%
plt.show()

# %%
k2 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRatings')

# %%
plt.show()

# %%
#subplots

f,ax = plt.subplots(1,2,figsize = (12,6))
#f,ax = plt.subplots(3,3,figsize = (12,6))

# %%
plt.show()

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(data=movies,x='BudgetMillion',y ='AudienceRatings',shade=True,shade_lowest=False,ax=axes[0])
k1 = sns.kdeplot(data=movies,x='BudgetMillion',y ='CriticRating',shade=False,shade_lowest=True,ax=axes[1])

# %%
plt.show()

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillion', ylabel='AudienceRatings'>,
#        <Axes: xlabel='BudgetMillion', ylabel='CriticRating'>],
#       dtype=object)

# %%
#Box plots -

w = sns.boxplot(data = movies, x ='Genre', y = 'CriticRating')

# %%
plt.show()

# %%
#Box plots -

w = sns.boxplot(data = movies, x ='Genre', y = 'CriticRating',palette='coolwarm')

# %%
plt.show()

# %%
#violin plot

z = sns.violinplot(data=movies, x='Genre', y = 'CriticRating',palette='coolwarm')

# %%
plt.show()

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating',palette ='coolwarm')

# %%
plt.show()

# %%
# Createing a Facet grid
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots

# %%
plt.show()

# %%
plt.scatter(data=movies,x='CriticRating',y='AudienceRatings')
sns.set_style('ticks')

# %%
plt.show()

# %%
# Scatter plot
plt.figure(figsize=(8,5))
plt.scatter(data=movies, x='CriticRating', y='AudienceRatings', alpha=0.5, color='red', edgecolors='black')
plt.show()

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings' ) #scatterplots are mapped in facetgrid
plt.show()

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillion') #scatterplots are mapped in facetgrid
plt.show()

# %%
#scatterplots are mapped in facetgrid
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings',**kws ) 
plt.show()

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(data=movies,x='BudgetMillion',y='AudienceRatings',ax=axes[0,0])
k2 = sns.kdeplot(data=movies,x='BudgetMillion',y='CriticRating',ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRatings',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(data=movies,x='CriticRating', y='AudienceRatings',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(data=movies,x='BudgetMillion',y='AudienceRatings', \
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(data=movies,x='BudgetMillion',y='AudienceRatings', \
                 cmap = 'coolwarm',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(data=movies,x='BudgetMillion',y='CriticRating',\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(data=movies,x='BudgetMillion',y='CriticRating',\
                  cmap = 'coolwarm', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRatings', \
                 shade = True,shade_lowest=False,cmap='Blues', \
                 ax=axes[1,1])

k4b = sns.kdeplot(data=movies,x='CriticRating',y='AudienceRatings', \
                  cmap='viridis',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %% [markdown]
# Final discussion what we learn so far - 1> category datatype in python 2> jointplots 3> histogram 4> stacked histograms 5> Kde plot 6> subplot 7> violin plots 8> Factet grid 9> Building dashboards
